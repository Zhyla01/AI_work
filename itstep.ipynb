# %% [markdown]
# <a href="https://www.kaggle.com/code/andreyzhyla/itstep?scriptVersionId=250902695" target="_blank"><img align="left" alt="Kaggle" title="Open in Kaggle" src="https://kaggle.com/static/images/open-in-kaggle.svg"></a>

# %%
#Завдання

# %%
import torch

# %%
def f(x):
    return x**2 / 3 + torch.sin(torch.pi * x)

y_true = 1

# %%
start_point = torch.tensor(1.2, device='cpu', requires_grad=True)

# %%
optimizer = torch.optim.SGD([start_point], lr=1e-3)

# %%
for i in range(2000):
    res_func = f(start_point)

    error = (y_true - res_func) ** 2

    error.backward()

    optimizer.step()

    optimizer.zero_grad()

    if i % 100 == 0:
        print(f'Ітерація {i}, помилка: {error.item():.6f}')

print()
print(f'Оптимальне x: {start_point.item():.6f}')
print(f'f(x): {f(start_point).item():.6f}')
# Out:
# Ітерація 0, помилка: 1.227189
# Ітерація 100, помилка: 0.138967
# Ітерація 200, помилка: 0.023805
# Ітерація 300, помилка: 0.006964
# Ітерація 400, помилка: 0.002618
# Ітерація 500, помилка: 0.001126
# Ітерація 600, помилка: 0.000524
# Ітерація 700, помилка: 0.000257
# Ітерація 800, помилка: 0.000130
# Ітерація 900, помилка: 0.000068
# Ітерація 1000, помилка: 0.000036
# Ітерація 1100, помилка: 0.000019
# Ітерація 1200, помилка: 0.000010
# Ітерація 1300, помилка: 0.000006
# Ітерація 1400, помилка: 0.000003
# Ітерація 1500, помилка: 0.000002
# Ітерація 1600, помилка: 0.000001
# Ітерація 1700, помилка: 0.000000
# Ітерація 1800, помилка: 0.000000
# Ітерація 1900, помилка: 0.000000
#
# Оптимальне x: 0.678978
# f(x): 0.999714
